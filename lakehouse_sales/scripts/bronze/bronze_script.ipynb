# %%
from bronze_config import ingestion_config

# %%
for i in ingestion_config:
    spark.sql(f"drop table if exists {i["table"]}")
    df=spark.read.option("header","true").option("inferschema","true").csv(i["path"])
    df.write.mode("overwrite").saveAsTable(i["table"])
