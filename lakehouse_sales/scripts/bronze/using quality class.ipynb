# %%
import quality_class as q

# %%
df=spark.table("sales.bronze.test")
df.display()

# %%
qr=q.QualityRunner(spark=spark,layer="bronze",alert_emails=["eyadfathyelnagdy@gmail.com","eyadelnagdyofficial@gmail.com"])

# %%
qr.check_nulls(df,table_name="sales.bronze.test",columns=["name"])

# %%
qr.check_duplicates(df,table_name="sales.bronze.test2",key_columns=["id"])

# %%
qr.commit(raise_on_critical=False)

# %%
# %sql
truncate table sales.audit.quality_log
